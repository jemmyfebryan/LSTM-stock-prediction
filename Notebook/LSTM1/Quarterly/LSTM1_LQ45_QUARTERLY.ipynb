# %% [markdown]
# # 02_LQ45_QUARTERLY

# %% [markdown]
# ### Metadata
#
#
# 1. `Date`: Tanggal pengamatan.
# 2. `Close Price`: Harga penutup saham pada hari tersebut.
# 3. `Open Price`: Harga pembukaan saham pada hari tersebut.
# 4. `High Price`: Harga tertinggi saham pada hari tersebut.
# 5. `Low Price`: Harga terendah saham pada hari tersebut.
# 6. `Close Price.1`: Harga penutup saham (mungkin data yang sama dengan 'Close Price').
# 7. `SMAVG(50)`: Rata-rata bergerak sederhana 50 hari.
# 8. `SMAVG(100)`: Rata-rata bergerak sederhana 100 hari.
# 9. `SMAVG(200)`: Rata-rata bergerak sederhana 200 hari.
# 10. `Volume`: Jumlah saham yang diperdagangkan pada hari tersebut.
# 11. `Price/Earnings`: Rasio harga terhadap laba bersih.
# 12. `Price/Earnings before XO, Positive`: Rasio harga terhadap laba bersih sebelum penyesuaian (mungkin saat ada peristiwa tertentu).
# 13. `Price/Earnings before XO`: Rasio harga terhadap laba bersih sebelum penyesuaian.
# 14. `Price/Cash Flow`: Rasio harga terhadap aliran kas.
# 15. `Price/Sales`: Rasio harga terhadap pendapatan penjualan.
# 16. `Price/Book Value`: Rasio harga terhadap nilai buku.
# 17. `RSI 14 Day`: Indeks kekuatan relatif untuk 14 hari.
# 18. `RSI 30 Day`: Indeks kekuatan relatif untuk 30 hari.
# 19. `RSI 9 Day`: Indeks kekuatan relatif untuk 9 hari.
# 20. `RSI 3 Day`: Indeks kekuatan relatif untuk 3 hari.
# 21. `Volatility 10D`: Volatilitas selama 10 hari.
# 22. `Volatility 30D`: Volatilitas selama 30 hari.
# 23. `Volatility 60D`: Volatilitas selama 60 hari.
# 24. `Volatility 90D`: Volatilitas selama 90 hari.
# 25. `Volatility 180D`: Volatilitas selama 180 hari.
# 26. `Volatility 360D`: Volatilitas selama 360 hari.
# 27. `IHSG 1 Day Ago`: Indeks Harga Saham Gabungan (IHSG) satu hari sebelumnya.
# 28. `Oil Price`: Harga minyak.
# 29. `Palm Oil Price`: Harga minyak kelapa sawit.
# 30. `Coal Price`: Harga batu bara.
# 31. `BI FX Rate`: Nilai tukar Rupiah terhadap mata uang asing (Bank Indonesia).
# 32. `5Y Bond Yield`: Imbal hasil obligasi 5 tahun.
# 33. `10Y Bond Yield`: Imbal hasil obligasi 10 tahun.
# 34. `JIBOR 3M`: Jakarta Interbank Offered Rate (JIBOR) untuk tenor 3 bulan.

# %% [markdown]
# ### Setup

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Load Data

# %%
def load_dataset(dataset_root, data_name, time_frame, separator):
    file_path = os.path.join(dataset_root, data_name, time_frame, f"{time_frame}.csv")

    if not os.path.isfile(file_path):
        raise FileNotFoundError(f"The file '{file_path}' does not exist.")

    df = pd.read_csv(file_path, sep = separator)

    return df

# %%
DATASET_ROOT = '/content/drive/MyDrive/Data'
data = '02_LQ45'
time_frame = 'Quarterly'

data = load_dataset(DATASET_ROOT, data, time_frame, ',')

# %%
data
# Out:
#           Date  3M Total Return - Last Close  Close Price   Volatility 90 Day  \
# 0   12/31/2022                     -0.070541        937.18              13.01
# 26            20.82        20.82             20.82      49.68          2400.0
# 27            18.29        18.29             18.29      39.60          2690.0
# 28            17.05        17.05             17.05      36.46          2292.0
# 29            14.82        14.82             14.82      48.37          2306.0
# 30            16.90        16.90             16.90      63.59          2224.0
# 31            18.92        18.92             18.92      55.11          2136.0
# 32            18.27        18.27             18.27      57.90          2300.0
# 33            17.56        17.56             17.56      94.67          2232.0
# 34            17.12        17.12             17.12     112.36          2448.0
# 35            16.73        16.73             16.73     108.07          2735.0
# 36            15.93        15.93             15.93     111.21          2603.0
# 37            16.15        16.15             16.15     108.37          2355.0
# 38            18.40        18.40             18.40     102.16          2337.0
# 39            17.69        17.69             17.69     110.02          2372.0
# 40            16.59        16.59             16.59     110.62          2367.0
#
#     Coal Price  BI FX Rate  5Y Bond Yield  10Y Bond Yield  JIBOR 3M
# 0       205.55    15731.00           6.20            6.94      6.62
# 1       295.00    15247.00           6.72            7.37      5.11
# 2       341.65    14848.00           6.13            7.22      3.75
# 3       254.35    14349.00           5.62            6.74      3.75
# 4       138.00    14265.00           5.10            6.38      3.75
# 5       200.50    14307.00           5.14            6.26      3.75
# 6       114.85    14496.00           5.40            6.59      3.75
# 7        96.85    14572.00           5.91            6.78      3.75
# 8        87.65    14105.01           5.21            5.89      4.06
# 9        62.25    14918.00           5.73            6.96      4.30
# 10       54.70    14302.00           6.54            7.21      4.66
# 11       74.00    16367.00           7.31            7.91      4.88
# 12       78.70    13945.01           6.45            7.10      5.51
# 13       64.05    14174.00           6.71            7.29      5.86
# 14       62.95    14141.00           6.87            7.37      6.95
# 15       77.10    14244.00           7.15            7.63      7.21
# 16       95.70    14542.00           7.90            8.02      7.70
# 17       98.80    14929.00           8.05            8.12      7.35
# 18      104.25    14404.00           7.57            7.80      7.10
# 19       91.55    13756.00           5.94            6.68      5.36
# 20       95.20    13548.00           5.96            6.32      5.48
# 21       91.55    13492.00           6.13            6.50      5.20
# 22       77.80    13319.00           6.67            6.83      7.01
# 23       79.50    13321.00           6.85            7.04      6.87
# 24       82.85    13436.00           7.58            7.97      7.46
# 25       67.65    12998.00           6.84            7.06      7.10
# 26       59.20    13180.00           7.32            7.45      7.23
# 27       53.15    13276.00           7.38            7.67      6.73
# 28       49.45    13794.00           8.84            8.98      8.82
# 29       49.65    14657.00           9.51            9.69      8.21
# 30       60.30    13332.00           8.28            8.38      6.98
# 31       58.65    13084.00           7.34            7.56      6.88
# 32       64.00    12436.00           7.78            7.88      7.17
# 33       65.55    12212.00           8.32            8.52      8.07
# 34       74.15    11969.00           7.84            8.21      8.15
# 35       74.60    11404.00           7.69            7.99      8.13
# 36       85.25    12270.00           8.07            8.48      7.80
# 37       77.25    11613.00           7.92            8.50      7.16
# 38       77.65     9929.00           6.41            7.13      5.36
# 39       83.35     9719.00           5.10            5.57      4.90
# 40       88.75     9670.00           4.81            5.19      5.02

# %%
# Step 1: Check the column names
print("Column names before:", data.columns)

# If there are leading or trailing spaces, remove them from column names
data.columns = data.columns.str.strip()

# Step 2: Check the column names after stripping spaces
print("Column names after:", data.columns)
# Out:
# Column names before: Index(['Date', '3M Total Return - Last Close', 'Close Price ',
#        'Volatility 90 Day', 'Return Sharpe Ratio', ' Sortino Ratio ',
#        'Price/Earnings', 'Price/Earnings before XO, Positive',
#        'Price/Earnings before XO', 'Price/Cash Flow', 'Price/Sales',
#        'Price/Book Value', 'Oil Price', 'Palm Oil Price', 'Coal Price',
#        'BI FX Rate', '5Y Bond Yield', '10Y Bond Yield', 'JIBOR 3M'],
#       dtype='object')
# Column names after: Index(['Date', '3M Total Return - Last Close', 'Close Price',
#        'Volatility 90 Day', 'Return Sharpe Ratio', 'Sortino Ratio',
#        'Price/Earnings', 'Price/Earnings before XO, Positive',
#        'Price/Earnings before XO', 'Price/Cash Flow', 'Price/Sales',
#        'Price/Book Value', 'Oil Price', 'Palm Oil Price', 'Coal Price',
#        'BI FX Rate', '5Y Bond Yield', '10Y Bond Yield', 'JIBOR 3M'],
#       dtype='object')

# %% [markdown]
# ### Checking null values

# %%
# Check the percentage of Nan in dataset
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum() / len(data)).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(15)
# Out:
#                                     Total  Percent
# Date                                    0      0.0
# Price/Sales                             0      0.0
# 10Y Bond Yield                          0      0.0
# 5Y Bond Yield                           0      0.0
# BI FX Rate                              0      0.0
# Coal Price                              0      0.0
# Palm Oil Price                          0      0.0
# Oil Price                               0      0.0
# Price/Book Value                        0      0.0
# Price/Cash Flow                         0      0.0
# 3M Total Return - Last Close            0      0.0
# Price/Earnings before XO                0      0.0
# Price/Earnings before XO, Positive      0      0.0
# Price/Earnings                          0      0.0
# Sortino Ratio                           0      0.0

# %% [markdown]
# ### Data Preprocessing

# %%
# Mengonversi kolom 'Date' menjadi tipe data datetime
data['Date'] = pd.to_datetime(data['Date'])

df = data.copy()

# Menjadikan kolom 'Date' sebagai indeks
df.set_index('Date', inplace=True)
df
# Out:
#             3M Total Return - Last Close  Close Price  Volatility 90 Day  \
# Date
# 2022-12-31                     -0.070541       937.18              13.01
# 2022-09-30                      0.021276      1011.48              15.32
# 2022-06-30                     -0.018467       991.94              18.32
# 2022-03-31                      0.098279      1022.99              13.31
# 2021-12-31                      0.044586       931.41              16.40
# 2021-09-30                      0.062393       894.68              16.80
# 2021-06-30                     -0.062856       844.85              16.77
# 2021-03-31                     -0.055682       902.79              22.92
# 2020-12-31                      0.270688       934.89              26.70
# 2020-09-30                     -0.022004       737.15              27.61
# 2020-06-30                      0.147096       756.20              52.89
# 2020-03-31                     -0.308291       691.13              45.34
# 2019-12-31                      0.050099      1014.47              14.93
# 2019-09-30                     -0.050491       968.15              15.39
# 2019-06-30                      0.022027      1013.96              16.81
# 2019-03-31                      0.035241      1019.04              14.18
# 2018-12-31                      0.046596       982.73              20.38
# 2018-09-30                      0.050551       946.15              24.45
# 2018-06-30                     -0.093786       908.97              22.85
# 2018-03-31                     -0.062463      1005.68              15.15
# 2017-12-31                      0.098686      1079.39              10.53
# 2017-09-30                     -0.015927       979.44              11.95
# 2017-06-30                      0.064945       977.62              11.61
# 2017-03-31                      0.049321       921.53              13.03
# 2016-12-31                     -0.038682       884.62              19.88
# 2016-09-30                      0.072377       922.20              17.45
# 2018-12-31            8.02      7.70
# 2018-09-30            8.12      7.35
# 2018-06-30            7.80      7.10
# 2018-03-31            6.68      5.36
# 2017-12-31            6.32      5.48
# 2017-09-30            6.50      5.20
# 2017-06-30            6.83      7.01
# 2017-03-31            7.04      6.87
# 2016-12-31            7.97      7.46
# 2016-09-30            7.06      7.10
# 2016-06-30            7.45      7.23
# 2016-03-31            7.67      6.73
# 2015-12-31            8.98      8.82
# 2015-09-30            9.69      8.21
# 2015-06-30            8.38      6.98
# 2015-03-31            7.56      6.88
# 2014-12-31            7.88      7.17
# 2014-09-30            8.52      8.07
# 2014-06-30            8.21      8.15
# 2014-03-31            7.99      8.13
# 2013-12-31            8.48      7.80
# 2013-09-30            8.50      7.16
# 2013-06-30            7.13      5.36
# 2013-03-31            5.57      4.90
# 2012-12-31            5.19      5.02

# %% [markdown]
# ### Handling Missing Values

# %%
def fillna_zero_selected_columns(df, columns):
    """
    Mengisi nilai NaN dengan nilai 0 untuk kolom yang dipilih dalam DataFrame.
    """
    return df.fillna({column: 0 for column in columns})

# Specify the columns to fill NaN with 0
selected_columns = ['News Publication', 'News Positive Sentiment', 'News Negative Sentiment', 'Twitter Publication', 'Twitter Positive Sentiment', 'Twitter Negative Sentiment']

# Fill NaN with 0 for the selected columns
df = fillna_zero_selected_columns(df, selected_columns)

# %%
def drop_columns_with_all_missing(df):
    # Menghapus kolom yang memiliki 100% missing value
    df_cleaned = df.dropna(axis=1, how='all')
    return df_cleaned
df = drop_columns_with_all_missing(df)

# %%
# Check the percentage of Nan in dfset
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum() / len(df)).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(15)
# Out:
#                                     Total  Percent
# 3M Total Return - Last Close            0      0.0
# Close Price                             0      0.0
# 10Y Bond Yield                          0      0.0
# 5Y Bond Yield                           0      0.0
# BI FX Rate                              0      0.0
# Coal Price                              0      0.0
# Palm Oil Price                          0      0.0
# Oil Price                               0      0.0
# Price/Book Value                        0      0.0
# Price/Sales                             0      0.0
# Price/Cash Flow                         0      0.0
# Price/Earnings before XO                0      0.0
# Price/Earnings before XO, Positive      0      0.0
# Price/Earnings                          0      0.0
# Sortino Ratio                           0      0.0

# %%
def handle_missing_values(df, column_name, method='ffill'):
    # Calculate the number of missing values before filling
    before_fill_count = df[column_name].isnull().sum()

    # Fill missing values using the specified method (default: forward fill)
    df[column_name] = df[column_name].fillna(method=method)

    # Calculate the number of missing values after filling
    after_fill_count = df[column_name].isnull().sum()

    # Print a summary of the missing value handling
    print(f"Handling missing values for '{column_name}':")
    print(f"Before filling: {before_fill_count} missing values")
    print(f"After filling: {after_fill_count} missing values")

    # Create boxplot and histogram for the column
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.boxplot(df[column_name])
    plt.title(f"Boxplot of {column_name}")
    plt.xlabel(column_name)

    plt.subplot(1, 2, 2)
    plt.hist(df[column_name])
    plt.title(f"Histogram of {column_name}")
    plt.xlabel(column_name)

    plt.show()

# %%
# Memeriksa apakah ada nilai yang hilang pada baris pertama
first_row_has_missing = df.iloc[0].isnull().any()

if first_row_has_missing:
    print("Ada nilai yang hilang pada baris pertama.")
else:
    print("Tidak ada nilai yang hilang pada baris pertama.")
# Out:
# Tidak ada nilai yang hilang pada baris pertama.

# %%
def fill_missing_values_first_row(df):
    # Iterasi melalui setiap kolom dalam DataFrame
    for column in df.columns:
        # Memeriksa apakah ada nilai yang hilang pada baris pertama kolom tertentu
        if pd.isnull(df.at[df.index[0], column]):
            # Mencari nilai terdekat yang tidak hilang (tidak NaN)
            nearest_value = df[column].dropna().iloc[0]
            # Menggantikan nilai yang hilang di baris pertama dengan nilai terdekat
            df.at[df.index[0], column] = nearest_value
    return df

# %%
df = fill_missing_values_first_row(df)
df
# Out:
#             3M Total Return - Last Close  Close Price  Volatility 90 Day  \
# Date
# 2022-12-31                     -0.070541       937.18              13.01
# 2022-09-30                      0.021276      1011.48              15.32
# 2022-06-30                     -0.018467       991.94              18.32
# 2022-03-31                      0.098279      1022.99              13.31
# 2021-12-31                      0.044586       931.41              16.40
# 2021-09-30                      0.062393       894.68              16.80
# 2021-06-30                     -0.062856       844.85              16.77
# 2021-03-31                     -0.055682       902.79              22.92
# 2020-12-31                      0.270688       934.89              26.70
# 2020-09-30                     -0.022004       737.15              27.61
# 2020-06-30                      0.147096       756.20              52.89
# 2020-03-31                     -0.308291       691.13              45.34
# 2019-12-31                      0.050099      1014.47              14.93
# 2019-09-30                     -0.050491       968.15              15.39
# 2019-06-30                      0.022027      1013.96              16.81
# 2019-03-31                      0.035241      1019.04              14.18
# 2018-12-31                      0.046596       982.73              20.38
# 2018-09-30                      0.050551       946.15              24.45
# 2018-06-30                     -0.093786       908.97              22.85
# 2018-03-31                     -0.062463      1005.68              15.15
# 2017-12-31                      0.098686      1079.39              10.53
# 2017-09-30                     -0.015927       979.44              11.95
# 2017-06-30                      0.064945       977.62              11.61
# 2017-03-31                      0.049321       921.53              13.03
# 2016-12-31                     -0.038682       884.62              19.88
# 2016-09-30                      0.072377       922.20              17.45
# 2016-06-30                      0.047758       860.72              13.48
# 2016-03-31                      0.076811       840.35              20.46
# 2015-12-31                      0.125858       792.03              30.33
# 2015-09-30                     -0.158073       704.98              26.43
# 2015-06-30                     -0.101165       839.14              16.90
# 2015-03-31                      0.069790       961.94              12.38
# 2014-12-31                      0.032893       898.58              14.67
# 2014-09-30                      0.063582       873.08              14.81
# 2014-06-30                      0.015518       822.67              19.38
# 2014-03-31                      0.107165       799.51              21.81
# 2013-12-31                      0.001310       711.14              28.34
# 2013-09-30                     -0.100848       712.90              38.11
# 2013-06-30                     -0.020849       804.00              25.92
# 2013-03-31                      0.128746       836.87              13.63
# 2012-12-31                      0.016320       735.04              12.17
#
#             Return Sharpe Ratio  Sortino Ratio  Price/Earnings  \
# Date
# 2022-12-31            -2.340640      -3.548637           14.48
# 2022-09-30             0.336458       1.161180           16.40
# 2022-06-30            -0.531429      -0.606261           14.12
# 2022-03-31             3.459518       9.123835           17.49
# 2021-12-31             0.945171       2.548711           18.90
# 2021-09-30             1.434245       3.799290           19.32
# 2021-06-30            -1.632890      -2.677870           21.68
# 2021-03-31            -1.169078      -1.979926           18.83
# 2020-12-31             6.663826      15.800279           19.48
# 2020-09-30            -0.510916      -0.590941           13.80
).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(15)
# Out:
#                                     Total  Percent
# 3M Total Return - Last Close            0      0.0
# Close Price                             0      0.0
# 10Y Bond Yield                          0      0.0
# 5Y Bond Yield                           0      0.0
# BI FX Rate                              0      0.0
# Coal Price                              0      0.0
# Palm Oil Price                          0      0.0
# Oil Price                               0      0.0
# Price/Book Value                        0      0.0
# Price/Sales                             0      0.0
# Price/Cash Flow                         0      0.0
# Price/Earnings before XO                0      0.0
# Price/Earnings before XO, Positive      0      0.0
# Price/Earnings                          0      0.0
# Sortino Ratio                           0      0.0

# %% [markdown]
# ### Visualization

# %%
# Step 1: Check the column names
print("Column names before:", df.columns)

# If there are leading or trailing spaces, remove them from column names
df.columns = df.columns.str.strip()

# Step 2: Check the column names after stripping spaces
print("Column names after:", df.columns)
# Out:
# Column names before: Index(['3M Total Return - Last Close', 'Close Price', 'Volatility 90 Day',
#        'Return Sharpe Ratio', 'Sortino Ratio', 'Price/Earnings',
#        'Price/Earnings before XO, Positive', 'Price/Earnings before XO',
#        'Price/Cash Flow', 'Price/Sales', 'Price/Book Value', 'Oil Price',
#        'Palm Oil Price', 'Coal Price', 'BI FX Rate', '5Y Bond Yield',
#        '10Y Bond Yield', 'JIBOR 3M'],
#       dtype='object')
# Column names after: Index(['3M Total Return - Last Close', 'Close Price', 'Volatility 90 Day',
#        'Return Sharpe Ratio', 'Sortino Ratio', 'Price/Earnings',
#        'Price/Earnings before XO, Positive', 'Price/Earnings before XO',
#        'Price/Cash Flow', 'Price/Sales', 'Price/Book Value', 'Oil Price',
#        'Palm Oil Price', 'Coal Price', 'BI FX Rate', '5Y Bond Yield',
#        '10Y Bond Yield', 'JIBOR 3M'],
#       dtype='object')

# %%
def visualize_heatmap(df):

    # Menghitung matriks korelasi
    correlation_matrix = df.corr()

    # Menentukan ukuran gambar
    plt.figure(figsize=(15, 10))

    # Menampilkan heatmap
    sns.heatmap(correlation_matrix,  cmap='coolwarm', fmt='.2f', linewidths=0.5)

    # Menyesuaikan tata letak
    plt.title('Heatmap of Column Correlations')
    plt.show()

# Panggil fungsi untuk menampilkan heatmap
visualize_heatmap(df)

# %%
def visualize_target_correlation(df, target_column='Close Price'):
    # Menghitung matriks korelasi antara target_column dan semua kolom lain
    correlation_with_target = df.corr()[target_column].sort_values(ascending=False)

    # Menentukan ukuran gambar
    plt.figure(figsize=(10, 8))

    # Menampilkan bar plot korelasi dengan menambahkan nilai korelasi
    sns.barplot(x=correlation_with_target.values, y=correlation_with_target.index, palette='viridis')

    # Menambahkan nilai korelasi pada setiap bar
    for i, value in enumerate(correlation_with_target.values):
        plt.text(value + 0.01, i, f'{value:.2f}', va='center', fontsize=10)

    # Menyesuaikan tata letak
    plt.title(f'Correlation with {target_column}')
    plt.show()

# Panggil fungsi untuk menampilkan korelasi dengan 'Close Price'
visualize_target_correlation(df)

# %%
def visualize_close_price_line_chart(df, target_column='Close Price'):
    # Menentukan ukuran gambar
    plt.figure(figsize=(14, 6))

    # Membuat line chart untuk 'Close Price'
    plt.plot(df.index, df[target_column], label=target_column, color='blue', linestyle='-')

    # Menambahkan label dan judul
    plt.xlabel('Date')
    plt.ylabel(target_column)
    plt.title(f'Line Chart of {target_column}')

    # Menambahkan legenda
    plt.legend()

    # Menyesuaikan tata letak
    plt.tight_layout()
    plt.show()

# Panggil fungsi untuk membuat line chart dari 'Close Price'
visualize_close_price_line_chart(df)

# %%
def visualize_boxplots(df):
    # Menentukan jumlah kolom dan baris untuk tata letak grid
    num_columns = df.shape[1]
    num_rows = (num_columns // 3) + (1 if num_columns % 3 > 0 else 0)

    # Menentukan ukuran gambar berdasarkan jumlah kolom
    plt.figure(figsize=(15, 5 * num_rows))

    # Menampilkan boxplot satu per satu
    for i, column in enumerate(df.columns, 1):
        plt.subplot(num_rows, 3, i)
        sns.boxplot(x=df[column])
        plt.title(f'Boxplot for {column}')

    # Menyesuaikan tata letak
    plt.tight_layout()
    plt.show()

# Panggil fungsi untuk menampilkan boxplot satu per satu
visualize_boxplots(df)

# %%
def visualize_histograms(df):
    # Menentukan jumlah kolom dan baris untuk tata letak grid
    num_columns = df.shape[1]
    num_rows = (num_columns // 3) + (1 if num_columns % 3 > 0 else 0)

    # Menentukan ukuran gambar berdasarkan jumlah kolom
    plt.figure(figsize=(15, 5 * num_rows))

    # Menampilkan histogram satu per satu
    for i, column in enumerate(df.columns, 1):
        plt.subplot(num_rows, 3, i)
        df[column].hist(bins=20)
        plt.title(f'Histogram for {column}')

    # Menyesuaikan tata letak
    plt.tight_layout()
    plt.show()

# Panggil fungsi untuk menampilkan histogram satu per satu
visualize_histograms(df)

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# Scatterplot Matrix
plt.figure(figsize=(15, 15))
scatter_matrix(df, figsize=(15, 16))
plt.show()

# %%
import itertools

def scatter_plot_target_vs_features(df, target_column="Close Price", figsize=(20, 20), columns_per_row=4):
    # Mengambil list nama kolom dari DataFrame
    columns = df.columns

    # Set rasio aspek pada rcParams
    plt.rcParams['figure.figsize'] = figsize
    plt.rcParams['figure.dpi'] = 100
    plt.rcParams['savefig.dpi'] = 100

    # Menentukan ukuran subplot
    total_columns = len(columns)
    total_rows = (total_columns - 1) // columns_per_row + 1
    fig, axes = plt.subplots(nrows=total_rows, ncols=columns_per_row, sharex='col', sharey='row', gridspec_kw={'hspace': 0.8, 'wspace': 0.8, 'width_ratios': [2]*columns_per_row, 'height_ratios': [2]*total_rows})

    # Loop melalui setiap pasangan kolom untuk membuat scatter plot
    for i, j in itertools.product(range(total_rows), range(columns_per_row)):
        index = i * columns_per_row + j
        if index < total_columns and columns[index] != target_column:
            axes[i, j].scatter(df[columns[index]], df[target_column], alpha=0.7)  # Gunakan alpha untuk memudahkan melihat sebaran
            axes[i, j].set_xlabel(columns[index])
            axes[i, j].set_ylabel(target_column)

    # Menampilkan plot
    plt.show()

# Menggunakan fungsi dengan DataFrame df dan kolom target "Close Price"
scatter_plot_target_vs_features(df, target_column="Close Price", columns_per_row=4)

# %% [markdown]
# ### Normalizing Data

# %%
# Inisialisasi MinMaxScaler
scaler = MinMaxScaler()

# Normalisasi seluruh data dalam DataFrame
df_norm = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
def split_dataset_by_date(df, start_date, end_date):
    return df[(df['Date'] >= start_date) & (df['Date'] < end_date)].set_index('Date')

# %%
df_norm.reset_index(inplace=True)

train_set = split_dataset_by_date(df_norm, '2012-12-01', '2017-12-01')
validation_set = split_dataset_by_date(df_norm, '2017-12-01', '2019-12-01')
test_set = split_dataset_by_date(df_norm, '2019-12-01', '2022-12-31')

# %%
print("Jumlah data pada set pelatihan:", len(train_set))
print("Jumlah data pada set validasi:", len(validation_set))
print("Jumlah data pada set pengujian:", len(test_set))
# Out:
# Jumlah data pada set pelatihan: 20
# Jumlah data pada set validasi: 8
# Jumlah data pada set pengujian: 12

# %%
X_train = train_set.iloc[:, 1:]
y_train = train_set.iloc[:,0]

# %%
X_valid = validation_set.iloc[:, 1:]
y_valid = validation_set.iloc[:,0]

# %%
X_test = test_set.iloc[:, 1:]
y_test = test_set.iloc[:,0]

# %%
def plot_time_series(train_set, validation_set, test_set):
    # Plot keseluruhan data
    plt.figure(figsize=(14, 6))

    # Plot y_train
    plt.plot(train_set.index, train_set['Close Price'], label='Train', color='blue', linewidth=1)

    # Plot y_val
    plt.plot(validation_set.index, validation_set['Close Price'], label='Validation', color='orange', linewidth=1)

    # Plot y_test
    plt.plot(test_set.index, test_set['Close Price'], label='Test', color='green', linewidth=1)

    # Menambahkan garis vertikal putus-putus sebagai pembatas
    plt.axvline(validation_set.index[-1], color='gray', linestyle='--', linewidth=1, label='Batas Train')
    plt.axvline(test_set.index[0], color='gray', linestyle='--', linewidth=1, label='Batas Test')
    plt.axvline(test_set.index[-1], color='gray', linestyle='--', linewidth=1, label='Batas Validation')

    # Menambahkan label dan judul
    plt.xlabel('Tanggal', fontsize=14)
    plt.ylabel('Close Price', fontsize=14)
    plt.title('Visualisasi Data Train, Validation, dan Test', fontsize=16)
    plt.legend(fontsize=12)

    # Menambahkan grid
    plt.grid(True, linestyle='--', alpha=0.7)

    # Menambahkan shadow pada area di bawah kurva
    plt.fill_between(train_set.index, train_set['Close Price'], color='blue', alpha=0.2)
    plt.fill_between(validation_set.index, validation_set['Close Price'], color='orange', alpha=0.2)
    plt.fill_between(test_set.index, test_set['Close Price'], color='green', alpha=0.2)

    plt.show()

# Panggil fungsi plot_time_series dengan dataset yang telah diberikan
plot_time_series(train_set, validation_set, test_set)

# %% [markdown]
# ### Modelling LSTM

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (20, 17)
# (20,)

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.LSTM(128, return_sequences=False, input_shape=(X_train.shape[1], 1)))
model.add(tf.keras.layers.Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 66689 (260.50 KB)
# Trainable params: 66689 (260.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2736 - mse: 0.2736 - val_loss: 0.1631 - val_mse: 0.1631
# Epoch 2/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1936 - mse: 0.1936 - val_loss: 0.0976 - val_mse: 0.0976
# Epoch 3/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1240 - mse: 0.1240 - val_loss: 0.0454 - val_mse: 0.0454
# Epoch 4/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0666 - mse: 0.0666 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 5/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 6/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0500 - val_mse: 0.0500
# Epoch 7/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0454 - mse: 0.0454 - val_loss: 0.0679 - val_mse: 0.0679
# Epoch 8/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0537 - val_mse: 0.0537
# Epoch 9/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0316 - val_mse: 0.0316
# Epoch 10/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0321 - mse: 0.0321 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 11/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0216 - mse: 0.0216 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 12/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 13/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 14/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0268 - mse: 0.0268 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 15/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 16/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0328 - mse: 0.0328 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 17/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0330 - mse: 0.0330 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 18/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0315 - mse: 0.0315 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 19/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0288 - mse: 0.0288 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 20/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0256 - mse: 0.0256 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 21/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0227 - mse: 0.0227 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 22/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 23/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 24/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 25/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 26/100
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0229 - mse: 0.0229 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 27/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 28/100
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 29/100
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 30/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 31/100
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 32/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 33/100
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 34/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 35/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 36/100
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 37/100
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 38/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 39/100
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 40/100
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 41/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 42/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 43/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 44/100
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 45/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 46/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 47/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 48/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 49/100
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 50/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 51/100
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 52/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 53/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 54/100
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 55/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 56/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 57/100
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 58/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 59/100
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 60/100
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 61/100
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 62/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 63/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 64/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 65/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 66/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 67/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 68/100
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 69/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 70/100
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 71/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 72/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 73/100
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 74/100
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 75/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 76/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 77/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 78/100
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 79/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 80/100
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 81/100
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 82/100
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 83/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 84/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 85/100
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 86/100
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 87/100
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 88/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 89/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 90/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 91/100
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 92/100
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 93/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 94/100
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 95/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 96/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 97/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 98/100
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 99/100
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 100/100
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0083 - val_mse: 0.0083

# %%
y_test_pred = model.predict(X_test)
y_test_pred
# Out:
# 1/1 [==============================] - 0s 445ms/step
# array([[0.61379486],
#        [0.59991145],
#        [0.72464585],
#        [0.6551888 ],
#        [0.67123294],
#        [0.6409044 ],
#        [0.6021623 ],
#        [0.7388207 ],
#        [0.45839587],
#        [0.5143533 ],
#        [0.20365618],
#        [0.60832375]], dtype=float32)

# %%
# Mengukur kinerja model pada set test
mse_test = mean_squared_error(y_test, y_test_pred)
print(f'Mean Squared Error (Test): {mse_test}')
# Out:
# Mean Squared Error (Test): 0.022932729880250965

# %%
def plot_prediction(y_true, y_pred, dataset_name):
    """
    Plot hasil prediksi dan nilai sebenarnya.

    Parameters:
    - y_true (pandas.Series): Seri nilai sebenarnya.
    - y_pred (pandas.Series): Seri hasil prediksi.
    - dataset_name (str): Nama dataset (contoh: 'Validasi' atau 'Test').

    Returns:
    - None
    """
    plt.figure(figsize=(12, 6))

    # Plot nilai sebenarnya
    plt.plot(y_true.index, y_true, label=f'Nilai Sebenarnya {dataset_name}', color='blue', alpha=0.7)

    # Plot hasil prediksi
    plt.plot(y_true.index, y_pred, label=f'Hasil Prediksi {dataset_name}', linestyle='--', color='orange')

    # Menambahkan judul dan label
    plt.title(f'Prediksi vs Nilai Sebenarnya (Set {dataset_name})', fontsize=16)
    plt.xlabel('Tanggal', fontsize=14)
    plt.ylabel('Nilai', fontsize=14)

    # Menambahkan legenda
    plt.legend(fontsize=12)

    # Menambahkan grid
    plt.grid(True, linestyle='--', alpha=0.7)

    # Menampilkan plot
    plt.show()


# Panggil fungsi plot_prediction untuk set test
plot_prediction(y_test, y_test_pred, 'Test')

# %% [markdown]
# ### Mengembalikan ke Data Awal

# %%
pred_df = pd.DataFrame(y_test_pred, columns=['Predicted_Column'])

# %%
test = X_test.copy()
test.reset_index(drop=True, inplace=True)
test['Y_Prediksi'] = pred_df['Predicted_Column']
test_col = test.columns.tolist()
test_col = test_col[-1:] + test_col[:-1]
test = test[test_col]

# %%
# Inverse transform the reshaped pred array
pred_denorm = scaler.inverse_transform(test)

# %%
pred_denorm_df = pd.DataFrame(pred_denorm, columns=test.columns)
pred_denorm_df.head()
# Out:
#    Y_Prediksi  Close Price  Volatility 90 Day  Return Sharpe Ratio  \
# 0    0.047083      1011.48              15.32             0.336458
# 1    0.039045       991.94              18.32            -0.531429
# 2    0.111264      1022.99              13.31             3.459518
# 3    0.071050       931.41              16.40             0.945171
# 4    0.080339       894.68              16.80             1.434245
#
#    Sortino Ratio  Price/Earnings  Price/Earnings before XO, Positive  \
# 0       1.161180           16.40                               16.40
# 1      -0.606261           14.12                               14.12
# 2       9.123835           17.49                               17.49
# 3       2.548711           18.90                               18.90
# 4       3.799290           19.32                               19.32
#
#    Price/Earnings before XO  Price/Cash Flow  Price/Sales  Price/Book Value  \
# 0                     16.40            16.40        16.40             16.40
# 1                     14.12            14.12        14.12             14.12
# 2                     17.49            17.49        17.49             17.49
# 3                     18.90            18.90        18.90             18.90
# 4                     19.32            19.32        19.32             19.32
#
#    Oil Price  Palm Oil Price  Coal Price  BI FX Rate  5Y Bond Yield  \
# 0      87.96          3327.0      295.00     15247.0           6.72
# 1     114.81          5088.0      341.65     14848.0           6.13
# 2     107.91          6391.0      254.35     14349.0           5.62
# 3      79.32          5150.0      138.00     14265.0           5.10
# 4      78.52          4833.0      200.50     14307.0           5.14
#
#    10Y Bond Yield  JIBOR 3M
# 0            7.37      5.11
# 1            7.22      3.75
# 2            6.74      3.75
# 3            6.38      3.75
# 4            6.26      3.75

# %%
def split_dataset_by_date(df, start_date, end_date):
    return df[(df['Date'] >= start_date) & (df['Date'] < end_date)].set_index('Date')

test_set = split_dataset_by_date(data, '2019-12-01', '2022-12-31')

y_test = test_set.iloc[:,0]

# %%
y_test.head()
# Out:
# Date
# 2022-09-30    0.021276
# 2022-06-30   -0.018467
# 2022-03-31    0.098279
# 2021-12-31    0.044586
# 2021-09-30    0.062393
# Name: 3M Total Return - Last Close, dtype: float64

# %%
def plot_prediction(y_true, y_pred, dataset_name):
    """
    Plot hasil prediksi dan nilai sebenarnya.

    Parameters:
    - y_true (pandas.Series): Seri nilai sebenarnya.
    - y_pred (pandas.Series): Seri hasil prediksi.
    - dataset_name (str): Nama dataset (contoh: 'Validasi' atau 'Test').

    Returns:
    - None
    """
    plt.figure(figsize=(12, 6))

    # Plot nilai sebenarnya
    plt.plot(y_true.index, y_true, label=f'Nilai Sebenarnya {dataset_name}', color='blue', alpha=0.7)

    # Plot hasil prediksi
    plt.plot(y_true.index, y_pred, label=f'Hasil Prediksi {dataset_name}', linestyle='--', color='orange')

    # Menambahkan judul dan label
    plt.title(f'Prediksi vs Nilai Sebenarnya (Set {dataset_name})', fontsize=16)
    plt.xlabel('Tanggal', fontsize=14)
    plt.ylabel('Nilai', fontsize=14)

    # Menambahkan legenda
    plt.legend(fontsize=12)

    # Menambahkan grid
    plt.grid(True, linestyle='--', alpha=0.7)

    # Menampilkan plot
    plt.show()


# Panggil fungsi plot_prediction untuk set test
plot_prediction(y_test, pred_denorm_df.Y_Prediksi, 'pred_denorm_df')
